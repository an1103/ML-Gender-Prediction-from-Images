# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('./data/robert.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

haar = cv2.CascadeClassifier('./data/haarcascade_frontalface_default.xml')
face = haar.detectMultiScale(gray, 1.3, 5)

# %%
face
# Out:
# array([[ 52,  76, 178, 178]], dtype=int32)

# %%
cv2.rectangle(img, (52, 76), (52+178,76+178), (0, 0, 255), 2)
plt.imshow(img)

# %%
crop = img[76: 76+178, 52:52+178]
cv2.imwrite('./data/cropped.jpg', crop)
# Out:
# True
